# %%
a=[[1,2],(3,4),{5,6}]
a
# Out:
# [[1, 2], (3, 4), {5, 6}]

# %%
b=dict(a)
b
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
print(list(b.values()))
for values in b.values():
    print(values)
# Out:
# [2, 4, 6]
# 2
# 4
# 6

# %%
for key,value in b.items():
    print(key,value)
# Out:
# 1 2
# 3 4
# 5 6

# %%
print(list(b.items()))
for item in b.items():
    print(item)
# Out:
# [(1, 2), (3, 4), (5, 6)]
# (1, 2)
# (3, 4)
# (5, 6)

# %%
c={7:8}

# %%
b.fromkeys(c)
# Out:
# {7: None}

# %%
print(b)
# Out:
# {1: 2, 3: 4, 5: 6}

# %% [markdown]
# # multiples and cubes

# %%
dict_a={}
for i in range(1,10):
    if i%3==0:
        dict_a[i]=[i**3]
print(dict_a)
# Out:
# {3: [27], 6: [216], 9: [729]}

# %%
dict_a={}
for i in range(1,10):
    if i%3==0:
        a=(i,i**3)
        dict_a.update({a[0]:a[1]})
print(dict_a)
# Out:
# {3: 27, 6: 216, 9: 729}

# %%
b
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
c={}
for keys,values in b.items():
    c[values]=keys
c
# Out:
# {2: 1, 4: 3, 6: 5, 1: 2, 3: 4}

# %%
a=[i**2 for i in range(1,5)]
a
# Out:
# [1, 4, 9, 16]

# %%
b=[i for i in a]

# %%
b
# Out:
# [1, 4, 9, 16]

# %%
c={i**2 for i in range(1,10)}
c
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81}

# %%
c={i for i in b}
c
# Out:
# {1, 4, 9, 16}

# %%
a=[i for i in range(1,10) if i%2==0]
a
# Out:
# [2, 4, 6, 8]

# %%
b=3
a=print("hey") if b==2 else "hello" if b%3==0 else "idiot"
a
# Out:
# 'hello'

# %%
a=int(input())
b=int(input())
c=[i for i in range(a,b) if i%2==0 and i%5==0]
c
# Out:
#  1
#  100
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
a=int(input())
b=int(input())
c=[i for i in range(a,b) if i%3==0 or i%5==0]
c
# Out:
#  1
#  10
# [3, 5, 6, 9]

# %%
a=set("aeiou")
l=['apple','ball','sky','gym']
b=[i for i in l if not set(i).isdisjoint(a)]
print(b)
# Out:
# ['apple', 'ball']

# %%
b=[]
for i in range(1,10):
    b.append(i**2 if i>0 and i%2==0 else  i**3 if i<0 and i%2==0 else i**(1/2) if i>0 else i**(1/3))
b
# Out:
# [1.0,
#  4,
#  1.7320508075688772,
#  16,
#  2.23606797749979,
#  36,
#  2.6457513110645907,
#  64,
#  3.0]

# %%
v=[i**2 if i>0 and i%2==0 else  i**3 if i<0 and i%2==0 else i**(1/2) if i>0 else i**(1/3) for i in range(-10,10)]
v
# Out:
# [-1000,
#  (1.0400419115259523+1.8014054327640039j),
#  -512,
#  (0.9564655913861947+1.656646999972302j),
#  -216,
#  (0.8549879733383486+1.480882609682364j),
#  -64,
#  (0.7211247851537043+1.2490247664834064j),
#  -8,
#  (0.5000000000000001+0.8660254037844386j),
#  0.0,
#  1.0,
#  4,
#  1.7320508075688772,
#  16,
#  2.23606797749979,
#  36,
#  2.6457513110645907,
#  64,
#  3.0]
